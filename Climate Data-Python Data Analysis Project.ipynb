# %% [markdown]
# # The Climate Dataset
#
# The Climate Dataset is a time-series data set with per-hour information about the weather conditions at a particular location.
# It records Temperature,Dew Point Temperature, Relative Humidity, Wind Speed, Visibility, Pressure, and Conditions.
#
#
# This data is available as a xlsx file. We are going to analyze this data set using the Pandas DataFrame

# %%
import pandas as pd

# %%
data = pd.read_excel('ClimateData.xlsx')

# %%
data
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0     2012-01-01 00:00:00    -1.8              -3.9         86
# 1     2012-01-01 01:00:00    -1.8              -3.7         87
# 2     2012-01-01 02:00:00    -1.8              -3.4         89
# 3     2012-01-01 03:00:00    -1.5              -3.2         88
# 4     2012-01-01 04:00:00    -1.5              -3.3         88
# ...                   ...     ...               ...        ...
# 8779     12/31/2012 19:00     0.1              -2.7         81
# 8780     12/31/2012 20:00     0.2              -2.4         83
# 8781     12/31/2012 21:00    -0.5              -1.5         93
# 8782     12/31/2012 22:00    -0.2              -1.8         89
# 8783     12/31/2012 23:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather
# 0                   4            8.0     101.24                   Fog
# ...

# %% [markdown]
# # In This Project ,We Will Use _ Various Command

# %% [raw]
# How To Analyze The DataFrame ?

# %%
Q1) .head()

     It Shows the First N Rows in the Data (By default N=5)

# %%
data.head()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1  2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2  2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3  2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4  2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
Q2)  .shape

     This Command is used to show the Total no of Rows and no of Columns of the Dataframe

# %%
data.shape
# Out:
# (8784, 8)

# %%
Q3)  .index

     This command shows the attribute provides the index of the dataframe

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
Q4) .columns
     
    This Command Shows the name odf each columns

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
Q5) .dtypes

    This command is used  to show the data type of each columns

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
Q6) .unique()

    This Command is Used  in a columns it will shows all the Unique values .It applied on a single column only not on whole 
    dataframe

# %%
data['Dew Point Temp_C'].unique()
# Out:
# array([ -3.9,  -3.7,  -3.4,  -3.2,  -3.3,  -3.1,  -3.6,  -2.3,  -2.1,
#         -2. ,  -1.7,  -1.1,  -0.4,  -0.2,   0. ,   1. ,   1.3,   1.7,
#          1.9,   2. ,   1.5,  -0.9,  -1.5,  -2.6,  -2.9,  -4.1,  -3.5,
#         -6.2,  -6.5,  -6.8,  -7. ,  -8.7,  -9.5, -11.4, -12.1, -13.4,
#        -12.8, -14.7, -14.1, -16. , -17.2, -15.8, -18.7, -20.1, -19.1,
#        -19.3, -19.5, -21.3, -21.9, -22.2, -22.6, -22.4, -22.9, -23.2,
#        -23.8, -24.8, -25.4, -24.6, -24.2, -24.1, -24. , -22.5, -20.6,
#        -21.1, -21.7, -19. , -16.3, -15.5, -13.2, -12.6, -12.7, -11.6,
#        -11.7, -10.2,  -8.3,  -7.7, -10.7,  -9.7,  -9.1, -10.1, -10. ,
#         -9.6, -12. , -14.4, -15.4, -15.7, -14.8, -16.8, -17.3, -16.5,
#        -16.1, -16.2, -16.7, -15.6, -14.3, -13.6, -13. , -12.5, -12.2,
#        -11.1, -10.8, -10.5,  -9. ,  -8. ,  -7.8,  -7.2,  -6.9,  -6.1,
#         -5.9,  -5.4,  -5.3,  -5. ,  -3. ,  -4.6,  -9.2, -10.3, -11.9,
# ...

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
Q7)  .nunique()

     This Command is used to show the total no of unique values in each columns.it can applied on a single column as well
    as on whole dataframe

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data['Weather'].nunique()
# Out:
# 50

# %%
Q8)  .count()

     This Command is used to show the total no of non-null value in each column.It can be applied on a single column as well
    as on whole DataFrame.

# %%
data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
data['Weather'].count()
# Out:
# 8784

# %%
Q9)  .value_counts()

     This Command is Used in a column.it shows all the unique values with their count.
      it can be applied on a single column only

# %%
data['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
Q10)  .info()

      This command provides the basic information about DataFrame.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# # Q1) Find all the Unique Wind Speed  values in the Data ?

# %%
data.head(2)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1  2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.nunique()      ## total 34 values are unique  vales in wind speed
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data['Wind Speed_km/h'].nunique()   ## total 34 values are unique  vales in wind speed
# Out:
# 34

# %%
data['Wind Speed_km/h'].unique()    # Answer
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %% [markdown]
# # Q2) Find the number of times when the " Weather is exactly Clear" ?

# %%
data.head(2)    #this are dataset
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1  2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
There are 3 ways of solving 

1 value_counts

2 Filtering

3 Groupby

# %%
#value_counts()

data['Weather'].value_counts()                     ### Total Clear -- is 1326
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
#Filtering

data[data.Weather == 'Clear']               #1326 rows all are clear
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 67    2012-03-01 19:00:00   -16.9             -24.8         50
# 114   2012-05-01 18:00:00    -7.1             -14.4         56
# 115   2012-05-01 19:00:00    -9.2             -15.4         61
# 116   2012-05-01 20:00:00    -9.8             -15.7         62
# 117   2012-05-01 21:00:00    -9.0             -14.8         63
# ...                   ...     ...               ...        ...
# 8646      12/26/2012 6:00   -13.4             -14.8         89
# 8698     12/28/2012 10:00    -6.1              -8.6         82
# 8713      12/29/2012 1:00   -11.9             -13.6         87
# 8714      12/29/2012 2:00   -11.8             -13.1         90
# 8756     12/30/2012 20:00   -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 67                 24           25.0     101.74   Clear
# 114                11           25.0     100.71   Clear
# ...

# %%
#Groupby 


data.groupby('Weather').get_group('Clear')
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 67    2012-03-01 19:00:00   -16.9             -24.8         50
# 114   2012-05-01 18:00:00    -7.1             -14.4         56
# 115   2012-05-01 19:00:00    -9.2             -15.4         61
# 116   2012-05-01 20:00:00    -9.8             -15.7         62
# 117   2012-05-01 21:00:00    -9.0             -14.8         63
# ...                   ...     ...               ...        ...
# 8646      12/26/2012 6:00   -13.4             -14.8         89
# 8698     12/28/2012 10:00    -6.1              -8.6         82
# 8713      12/29/2012 1:00   -11.9             -13.6         87
# 8714      12/29/2012 2:00   -11.8             -13.1         90
# 8756     12/30/2012 20:00   -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 67                 24           25.0     101.74   Clear
# 114                11           25.0     100.71   Clear
# ...

# %% [markdown]
# # Q3) Find the number of times when the " Weather is exactly Rain Showers" ?

# %%
data.head(2)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1  2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
#By using value_counts()


data['Weather'].value_counts()                #188  counts
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
#By Using Filtering Method

data[data['Weather'] == 'Rain Showers']
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 22    2012-01-01 22:00:00     4.4               1.9         84
# 24    2012-02-01 00:00:00     5.2               1.5         77
# 1263      2/22/2012 15:00     5.4              -1.4         62
# 1272       2/23/2012 0:00     2.3              -0.9         79
# 1499  2012-03-03 11:00:00     4.0              -0.7         71
# ...                   ...     ...               ...        ...
# 8076  2012-02-12 12:00:00     6.6               3.3         79
# 8120  2012-04-12 08:00:00     5.5               3.9         89
# 8121  2012-04-12 09:00:00     5.9               4.8         93
# 8131  2012-04-12 19:00:00    10.7               8.4         86
# 8363     12/14/2012 11:00     2.6              -2.0         72
#
#       Wind Speed_km/h  Visibility_km  Press_kPa       Weather
# 22                 24           19.3      99.32  Rain Showers
# 24                 35           25.0      99.26  Rain Showers
# ...

# %%
#Bygroup 


data.groupby('Weather').get_group('Rain Showers')
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 22    2012-01-01 22:00:00     4.4               1.9         84
# 24    2012-02-01 00:00:00     5.2               1.5         77
# 1263      2/22/2012 15:00     5.4              -1.4         62
# 1272       2/23/2012 0:00     2.3              -0.9         79
# 1499  2012-03-03 11:00:00     4.0              -0.7         71
# ...                   ...     ...               ...        ...
# 8076  2012-02-12 12:00:00     6.6               3.3         79
# 8120  2012-04-12 08:00:00     5.5               3.9         89
# 8121  2012-04-12 09:00:00     5.9               4.8         93
# 8131  2012-04-12 19:00:00    10.7               8.4         86
# 8363     12/14/2012 11:00     2.6              -2.0         72
#
#       Wind Speed_km/h  Visibility_km  Press_kPa       Weather
# 22                 24           19.3      99.32  Rain Showers
# 24                 35           25.0      99.26  Rain Showers
# ...

# %% [markdown]
# # Q4) Find the number of times when the "Wind Speed was exactly 4km/h " ?

# %%
data.head()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1  2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2  2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3  2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4  2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data['Wind Speed_km/h'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        4
# 1        4
# 2        7
# 3        6
# 4        7
#         ..
# 8779    30
# 8780    24
# 8781    28
# 8782    28
# 8783    30
# Name: Wind Speed_km/h, Length: 8784, dtype: int64>

# %%
data[data['Wind Speed_km/h']== 4]
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0     2012-01-01 00:00:00    -1.8              -3.9         86
# 1     2012-01-01 01:00:00    -1.8              -3.7         87
# 96    2012-05-01 00:00:00    -8.8             -11.7         79
# 101   2012-05-01 05:00:00    -7.0              -9.5         82
# 146   2012-07-01 02:00:00    -8.1             -11.1         79
# ...                   ...     ...               ...        ...
# 8768      12/31/2012 8:00    -8.6             -10.3         87
# 8769      12/31/2012 9:00    -8.1              -9.6         89
# 8770     12/31/2012 10:00    -7.4              -8.9         89
# 8772     12/31/2012 12:00    -5.8              -7.5         88
# 8773     12/31/2012 13:00    -4.6              -6.6         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa       Weather
# 0                   4            8.0     101.24           Fog
# 1                   4            8.0     101.24           Fog
# ...

# %%
data.groupby('Wind Speed_km/h').get_group(4)
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0     2012-01-01 00:00:00    -1.8              -3.9         86
# 1     2012-01-01 01:00:00    -1.8              -3.7         87
# 96    2012-05-01 00:00:00    -8.8             -11.7         79
# 101   2012-05-01 05:00:00    -7.0              -9.5         82
# 146   2012-07-01 02:00:00    -8.1             -11.1         79
# ...                   ...     ...               ...        ...
# 8768      12/31/2012 8:00    -8.6             -10.3         87
# 8769      12/31/2012 9:00    -8.1              -9.6         89
# 8770     12/31/2012 10:00    -7.4              -8.9         89
# 8772     12/31/2012 12:00    -5.8              -7.5         88
# 8773     12/31/2012 13:00    -4.6              -6.6         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa       Weather
# 0                   4            8.0     101.24           Fog
# 1                   4            8.0     101.24           Fog
# ...

# %% [markdown]
# # Q5) Find the number of times when the "Wind Speed was exactly 30km/h " ?

# %%
#Groupby

data.groupby('Wind Speed_km/h').get_group(30)
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 23    2012-01-01 23:00:00     5.3               2.0         79
# 35    2012-02-01 11:00:00     2.2              -3.5         66
# 170   2012-08-01 02:00:00    -1.7              -6.2         71
# 216   2012-10-01 00:00:00     2.5              -5.2         57
# 221   2012-10-01 05:00:00     0.8              -1.2         86
# ...                   ...     ...               ...        ...
# 8664      12/27/2012 0:00    -9.8             -12.5         81
# 8666      12/27/2012 2:00    -8.5             -11.3         80
# 8704     12/28/2012 16:00    -7.7             -11.0         77
# 8779     12/31/2012 19:00     0.1              -2.7         81
# 8783     12/31/2012 23:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa        Weather
# 23                 30           25.0      99.31         Cloudy
# 35                 30           24.1      99.19  Mostly Cloudy
# ...

# %% [markdown]
# # Q6) Find out all the Null Values in the data ?

# %%
data.head()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1  2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2  2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3  2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4  2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.isnull()   #this data is display in Boolean form  But i want data in col
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0         False   False             False      False            False
# 1         False   False             False      False            False
# 2         False   False             False      False            False
# 3         False   False             False      False            False
# 4         False   False             False      False            False
# ...         ...     ...               ...        ...              ...
# 8779      False   False             False      False            False
# 8780      False   False             False      False            False
# 8781      False   False             False      False            False
# 8782      False   False             False      False            False
# 8783      False   False             False      False            False
#
#       Visibility_km  Press_kPa  Weather
# 0             False      False    False
# 1             False      False    False
# ...

# %%
data.isnull().sum()       # this showing ther no null value
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.notnull().sum()     #there no null value in this data
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# # Q7) Rename the Column name 'Weather' of the Dataframe to 'Weather Conditions ?

# %%
data.head()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1  2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2  2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3  2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4  2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.rename(columns = {'Weather' :'Weather Conditions'})
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0     2012-01-01 00:00:00    -1.8              -3.9         86
# 1     2012-01-01 01:00:00    -1.8              -3.7         87
# 2     2012-01-01 02:00:00    -1.8              -3.4         89
# 3     2012-01-01 03:00:00    -1.5              -3.2         88
# 4     2012-01-01 04:00:00    -1.5              -3.3         88
# ...                   ...     ...               ...        ...
# 8779     12/31/2012 19:00     0.1              -2.7         81
# 8780     12/31/2012 20:00     0.2              -2.4         83
# 8781     12/31/2012 21:00    -0.5              -1.5         93
# 8782     12/31/2012 22:00    -0.2              -1.8         89
# 8783     12/31/2012 23:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa    Weather Conditions
# 0                   4            8.0     101.24                   Fog
# ...

# %%
data.head(2)    # The Column name is Showing "Weather" bcoz its not change permanetly
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1  2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.rename (columns = {'Weather' : 'Weather Conditions'} , inplace= True)   # Column name channges Permanetly 
                                                                                #by using inplace=true

# %%
data.head(1)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
#
#    Visibility_km  Press_kPa Weather Conditions
# 0            8.0     101.24                Fog

# %%
data.head(1)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
#
#    Visibility_km  Press_kPa Weather Conditions
# 0            8.0     101.24                Fog

# %% [markdown]
# # Q8) What is the mean "Visibilty"?

# %%
data.head(1)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
#
#    Visibility_km  Press_kPa Weather Conditions
# 0            8.0     101.24                Fog

# %%
data.Visibility_km.mean()
# Out:
# 27.664446721311478

# %%
data.Visibility_km.mode()
# Out:
# 0    25.0
# Name: Visibility_km, dtype: float64

# %%
data.Visibility_km.median()
# Out:
# 25.0

# %% [markdown]
# # Q9) What is the Standard Deviation of " Pressure" in the Data ?

# %%
data.head(1)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
#
#    Visibility_km  Press_kPa Weather Conditions
# 0            8.0     101.24                Fog

# %%
data.Press_kPa.std()
# Out:
# 0.8440047459486474

# %%
data['Press_kPa'].std()
# Out:
# 0.8440047459486474

# %% [markdown]
# # Q10) What is the Variance of 'Relative Humidity' in the Data ?

# %%
data.tail(1)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather Conditions
# 8783           11.3      99.89               Snow

# %%
data['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %% [markdown]
# # Q11) Find all the instances when 'Snow' was recorded ?

# %%
data.head(2)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1  2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Conditions
# 0            8.0     101.24                Fog
# 1            8.0     101.24                Fog

# %%
data['Weather Conditions'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
#GroupBy

data.groupby('Weather Conditions').get_group('Snow')
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 55    2012-03-01 07:00:00   -14.0             -19.5         63
# 84    2012-04-01 12:00:00   -13.7             -21.7         51
# 86    2012-04-01 14:00:00   -11.3             -19.0         53
# 87    2012-04-01 15:00:00   -10.2             -16.3         61
# 88    2012-04-01 16:00:00    -9.4             -15.5         61
# ...                   ...     ...               ...        ...
# 8779     12/31/2012 19:00     0.1              -2.7         81
# 8780     12/31/2012 20:00     0.2              -2.4         83
# 8781     12/31/2012 21:00    -0.5              -1.5         93
# 8782     12/31/2012 22:00    -0.2              -1.8         89
# 8783     12/31/2012 23:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Conditions
# 55                 19           25.0     100.95               Snow
# 84                 11           24.1     101.25               Snow
# ...

# %%
#Filtering 

data[data['Weather Conditions']=='Snow']
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 55    2012-03-01 07:00:00   -14.0             -19.5         63
# 84    2012-04-01 12:00:00   -13.7             -21.7         51
# 86    2012-04-01 14:00:00   -11.3             -19.0         53
# 87    2012-04-01 15:00:00   -10.2             -16.3         61
# 88    2012-04-01 16:00:00    -9.4             -15.5         61
# ...                   ...     ...               ...        ...
# 8779     12/31/2012 19:00     0.1              -2.7         81
# 8780     12/31/2012 20:00     0.2              -2.4         83
# 8781     12/31/2012 21:00    -0.5              -1.5         93
# 8782     12/31/2012 22:00    -0.2              -1.8         89
# 8783     12/31/2012 23:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Conditions
# 55                 19           25.0     100.95               Snow
# 84                 11           24.1     101.25               Snow
# ...

# %%
data[data['Weather Conditions']=='Snow'].tail(50)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8496   12/20/2012 0:00     0.4              -2.1         83               20
# 8502   12/20/2012 6:00    -1.6              -4.2         82               15
# 8507  12/20/2012 11:00    -1.1              -4.0         81                4
# 8530  12/21/2012 10:00     1.0               0.0         93               32
# 8531  12/21/2012 11:00     0.9               0.0         94               30
# 8532  12/21/2012 12:00     1.3               0.3         93               41
# 8533  12/21/2012 13:00     1.8               0.3         90               41
# 8542  12/21/2012 22:00     0.7               0.0         95               28
# 8548   12/22/2012 4:00     0.6              -0.6         92               35
# 8549   12/22/2012 5:00    -0.9              -1.9         93               35
# 8550   12/22/2012 6:00    -1.6              -3.0         90               41
# ...

# %%
data[data['Weather Conditions'].str.contains('Snow')].tail(50)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8680  12/27/2012 16:00    -4.5              -6.2         88               37
# 8681  12/27/2012 17:00    -4.2              -5.9         88               32
# 8682  12/27/2012 18:00    -4.0              -5.7         88               28
# 8683  12/27/2012 19:00    -3.9              -5.6         88               26
# 8684  12/27/2012 20:00    -3.7              -5.3         89               37
# 8685  12/27/2012 21:00    -3.7              -4.8         92               24
# 8686  12/27/2012 22:00    -3.8              -4.6         94               20
# 8687  12/27/2012 23:00    -4.0              -5.6         89               24
# 8688   12/28/2012 0:00    -4.2              -5.7         89               19
# 8689   12/28/2012 1:00    -4.4              -6.6         85               15
# 8690   12/28/2012 2:00    -4.3              -6.3         86               11
# ...

# %% [markdown]
# # Q12) Find all the instances when "Wind Speed is above 24" and 'Visibilty is 25'?

# %%
data.head(2)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1  2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Conditions
# 0            8.0     101.24                Fog
# 1            8.0     101.24                Fog

# %%
data[(data['Wind Speed_km/h'] >24 ) & (data['Visibility_km']==25)]
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 23    2012-01-01 23:00:00     5.3               2.0         79
# 24    2012-02-01 00:00:00     5.2               1.5         77
# 25    2012-02-01 01:00:00     4.6               0.0         72
# 26    2012-02-01 02:00:00     3.9              -0.9         71
# 27    2012-02-01 03:00:00     3.7              -1.5         69
# ...                   ...     ...               ...        ...
# 8705     12/28/2012 17:00    -8.6             -12.0         76
# 8753     12/30/2012 17:00   -12.1             -15.8         74
# 8755     12/30/2012 19:00   -13.4             -16.5         77
# 8759     12/30/2012 23:00   -12.1             -15.1         78
# 8760      12/31/2012 0:00   -11.1             -14.4         77
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Conditions
# 23                 30           25.0      99.31             Cloudy
# 24                 35           25.0      99.26       Rain Showers
# ...

# %% [markdown]
# # Q13)What is the Mean Value of each Column against each "Weather Conditions" ?

# %%
data.head(2)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1  2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Conditions
# 0            8.0     101.24                Fog
# 1            8.0     101.24                Fog

# %%
data.groupby('Weather Conditions').mean()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_4808\597518769.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Weather Conditions').mean()
#                                             Temp_C  Dew Point Temp_C  \
# Weather Conditions
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# ...

# %% [markdown]
# # Q14)What is the Maximum and Minimum  Value of each Column against each "Weather Conditions" ?

# %%
data.head(2)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1  2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Conditions
# 0            8.0     101.24                Fog
# 1            8.0     101.24                Fog

# %%
data.groupby('Weather Conditions').max()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_4808\2781619301.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   data.groupby('Weather Conditions').max()
#                                          Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather Conditions
# Clear                                      32.8              20.4         99
# Cloudy                                     30.5              22.6         99
# Drizzle                                    18.8              17.7         96
# Drizzle,Fog                                19.9              19.1        100
# Drizzle,Ice Pellets,Fog                     0.4              -0.7         92
# Drizzle,Snow                                1.2               0.2         95
# Drizzle,Snow,Fog                            1.1               0.6         98
# ...

# %%
data.groupby('Weather Conditions').min()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_4808\1639232814.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   data.groupby('Weather Conditions').min()
#                                          Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather Conditions
# Clear                                     -23.3             -28.5         20
# Cloudy                                    -21.4             -26.8         18
# Drizzle                                     1.1              -0.2         74
# Drizzle,Fog                                 0.0              -1.6         85
# Drizzle,Ice Pellets,Fog                     0.4              -0.7         92
# Drizzle,Snow                                0.9               0.1         92
# Drizzle,Snow,Fog                            0.3              -0.1         92
# ...

# %% [markdown]
# # Q15) Show all the Records where Weather Conditions is Fog ?

# %%
data.head(2)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1  2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Conditions
# 0            8.0     101.24                Fog
# 1            8.0     101.24                Fog

# %%
data.groupby('Weather Conditions').get_group('Fog')
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0     2012-01-01 00:00:00    -1.8              -3.9         86
# 1     2012-01-01 01:00:00    -1.8              -3.7         87
# 4     2012-01-01 04:00:00    -1.5              -3.3         88
# 5     2012-01-01 05:00:00    -1.4              -3.3         87
# 6     2012-01-01 06:00:00    -1.5              -3.1         89
# ...                   ...     ...               ...        ...
# 8716      12/29/2012 4:00   -16.0             -17.2         90
# 8717      12/29/2012 5:00   -14.8             -15.9         91
# 8718      12/29/2012 6:00   -13.8             -15.3         88
# 8719      12/29/2012 7:00   -14.8             -16.4         88
# 8722     12/29/2012 10:00   -12.0             -13.3         90
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Conditions
# 0                   4            8.0     101.24                Fog
# 1                   4            8.0     101.24                Fog
# ...

# %%
Q16) Find all instances when "Weather Conditions is Clear" or 'Visibility is above 40' ?

# %%
data.head(1)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
#
#    Visibility_km  Press_kPa Weather Conditions
# 0            8.0     101.24                Fog

# %%
 data[(data['Weather Conditions'] =='Clear') |  (data['Visibility_km'] > 40)]
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 67    2012-03-01 19:00:00   -16.9             -24.8         50
# 106   2012-05-01 10:00:00    -6.0             -10.0         73
# 107   2012-05-01 11:00:00    -5.6             -10.2         70
# 108   2012-05-01 12:00:00    -4.7              -9.6         69
# 109   2012-05-01 13:00:00    -4.4              -9.7         66
# ...                   ...     ...               ...        ...
# 8749     12/30/2012 13:00   -12.4             -16.2         73
# 8750     12/30/2012 14:00   -11.8             -16.1         70
# 8751     12/30/2012 15:00   -11.3             -15.6         70
# 8752     12/30/2012 16:00   -11.4             -15.5         72
# 8756     12/30/2012 20:00   -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Conditions
# 67                 24           25.0     101.74              Clear
# 106                17           48.3     100.45       Mainly Clear
# ...

# %%
Q16) Find all the Instances when :
    
    A. "Weather Conditions is Clear " and  "Relative Humidity is Greater than 50"
    
    or
    
    B. "Visibility is above 50"

# %%
data.head(2)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1  2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Conditions
# 0            8.0     101.24                Fog
# 1            8.0     101.24                Fog

# %%
data[(data['Weather Conditions'] =='Clear')  &  (data['Rel Hum_%'] > 50) | (data['Visibility_km'] >50)]
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 114   2012-05-01 18:00:00    -7.1             -14.4         56
# 115   2012-05-01 19:00:00    -9.2             -15.4         61
# 116   2012-05-01 20:00:00    -9.8             -15.7         62
# 117   2012-05-01 21:00:00    -9.0             -14.8         63
# 241   2012-11-01 01:00:00   -10.7             -17.8         56
# ...                   ...     ...               ...        ...
# 8646      12/26/2012 6:00   -13.4             -14.8         89
# 8698     12/28/2012 10:00    -6.1              -8.6         82
# 8713      12/29/2012 1:00   -11.9             -13.6         87
# 8714      12/29/2012 2:00   -11.8             -13.1         90
# 8756     12/30/2012 20:00   -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Conditions
# 114                11           25.0     100.71              Clear
# 115                 7           25.0     100.80              Clear
# ...
